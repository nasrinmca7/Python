# %%
#1.Find the error in the following Python code:

for i in range(5):
    print(i)

# Error: semicolon missing
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#2.What will be the output of this code?

a = 10
b = "5"
#print(a + b)

# Error: Python cannot add number and text, either we need to specify type as string for variable "a" or type as int for variable "b" 
# below are the corrected code
print(a + int(b))
print(str(a) + b)
# Out:
# 15
# 105

# %%
#3.What is the issue in this Python snippet?

def add_numbers(a, b):
   return a + b

# No Error - may be intendation or need to call that function

# %%
#4.Identify the bug in the following Python code:

numbers = [1, 2, 3, 4]
#print(numbers[4])

# Error: list have (0,1,2,3) numbers, but we are printing list , which is out of range - indexing error
# can be written as below:
print(numbers[3])
# Out:
# 4

# %%
#5.Find the error in the following Python code:
# print "Hello, World!"

# Error: Parentheses missing
# can be written as below:
print("Hello, world!")
# Out:
# Hello, world!

# %%
#6.Find the error in the following Python code:
x = 5 / 0

# Error: ZeroDivisionError - because Python cannot divide by zero.
# can write a code to Check for denominator before dividing: ex: if (denominator != 0):
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[10], line 2
#       1 #6.Find the error in the following Python code:
# ----> 2 x = 5 / 0
#
# ZeroDivisionError: division by zero

# %%
#7.Find the error in the following Python code:
name = "Alice"
age = 25
# print("Name: " + name + ", Age: " + age)

# Error: TypeError: can only concatenate str (not "int") to str
# can be written as below:
print("Name: " + name + ", Age: " + str(age))
# Out:
# Name: Alice, Age: 25

# %%
#8.Find the error
for i in range(1, 10, -1):
    print(i)
    
# Error: -1 means count backward, but the start value is 1 and the stop value is 10. That does not work, so the loop prints nothing.

# %%
#9. Find the error in the following Python code:
x = 10
if x = 5:
    print("x is 5")

# Error: "=" is for assigning a value. "=="is for checking if two values are equal.
# can be written as below:
# if x == 5
# Out:
#   Cell In[13], line 3
#     if x = 5:
#        ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
#10. Identify the error in the following function definition:

def greet(name)
    print("Hello, " + name)

#Error: ":" is missing in function definition
# can be written as: def greet(name):
