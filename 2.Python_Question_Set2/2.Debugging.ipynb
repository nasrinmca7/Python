# %%
#1.Find the error in the following Python code:
import math
print(math.sqrt(16))
# "Math" is in camelcase, it should be "math"
# Out:
# 4.0

# %%
#2.Find the error in the following Python code:
def my_function():
    global x #Explicitly declare x as global
    x += 5
    print(x)

x = 10
my_function() #this will print: 15
# Out:
# 15

# %%
#3.x = 5 , find error
if x == 10: # "==" is missing
    print("x is 10")

# %%
#4.
numbers = [5, 3, 8, 2]
# print(numbers.sort()) print none

numbers.sort()          # This changes the list to [2, 3, 5, 8]
print(numbers)          # This will print: [2, 3, 5, 8]
# Out:
# [2, 3, 5, 8]

# %%
#5.
def square(n):
    return n * n  # Added 'return' to send the result back
print(square(4))  # This will print: 16
# Out:
# 16

# %%
#6.
# my_tuple = (1, 2, 3)
# my_tuple[1] = 5

#Tuples in Python are immutable. 
#This means once a tuple is created, its values cannot be changed, added, or removed. 
#You are getting an error because you are trying to modify the value at index 1 (2) to 5.

my_list = [1, 2, 3]  # Changed to a list
my_list[1] = 5       
print(my_list)       # This will print: [1, 5, 3]
# Out:
# [1, 5, 3]

# %%
#7.
name = "Alice"
age = 25
print("My name is %s and I am %d years old" % (name, age))  # Added ', age'
# Out:
# My name is Alice and I am 25 years old

# %%
#8.
a = [1, 2, 3]
b = [1, 2, 3]
if a == b: # Changed 'is' to '=='
    print("Lists are equal")
# Out:
# Lists are equal

# %%
#9.
for i in range(5, 1, -1): # Added -1 as the step
    print(i)
# Out:
# 5
# 4
# 3
# 2

# %%
#10.
student = {"name": "John", "age": 20}
print(student["name"]) # Added quotes around "name"
# Out:
# John
