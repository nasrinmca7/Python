# %%
age = int( input("Enter the age"))
if(age == 18):
    print("Adult")
# Out:
# Enter the age 18
# Adult

# %%
age = int(input("Enter age"))
if(age >18 ):
    print("Major")
else:
    print("Minor")
# Out:
# Enter age 37
# Major

# %%
age = int(input("Enter age"))
if(age < 2):
    print("baby")
elif(age < 5):
    print("toddler")
elif(age < 12):
    print("boy")
else:
    print("adult")
# Out:
# Enter age 4
# toddler

# %%
lists = [13, 4, 1, 2, 5]
for age in lists:
    if(age < 2):
        print("baby")
    elif(age < 5):
        print("toddler")
    elif(age < 12):
        print("boy")
    else:
        print("adult")
# Out:
# adult
# toddler
# baby
# toddler
# boy
